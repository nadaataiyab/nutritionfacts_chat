# %%
import os
import pandas as pd

from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api._errors import TranscriptsDisabled
from dotenv import load_dotenv

# %%
# Get api keys
load_dotenv()
YOUTUBE_APIKEY = os.environ['YOUTUBE_APIKEY']
OPENAI_APIKEY = os.environ['OPENAI_APIKEY']

# %%
# Initialiaze youtube api client
youtube = build('youtube', 'v3', developerKey=YOUTUBE_APIKEY)

# %%
# Let's see what's available in the channels list api
#https://developers.google.com/youtube/v3/docs/channels/list
username = 'NutritionFactsOrg'
request = youtube.channels().list(
        part="id",
        forUsername=username
    )
response = request.execute()
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'y2wbGNYxO1mQLSW8NgLvKwMoFvQ',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'QrBFR4pa4iZJUXj0kXL8bnskofE',
#    'id': 'UCddn8dUxYdgJz3Qr5mjADtA'}]}

# %%
# Let's see what's available in the channels list api
username = 'NutritionFactsOrg'
request = youtube.channels().list(
        part="statistics",
        forUsername=username
    )
response = request.execute()
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'Nd35sJutPw9BcdfgNIQPGbqIVL8',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'p4XTTWuzBdOOveeFuWt47K3KG8o',
#    'id': 'UCddn8dUxYdgJz3Qr5mjADtA',
#    'statistics': {'viewCount': '239767241',
#     'subscriberCount': '1110000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '2596'}}]}

# %%
# Get youtube channel ID with some better code!

def get_channel_id_by_username(username):
    request = youtube.channels().list(
        part='id',
        forUsername=username
    )
    response = request.execute()

    if response['items']:
        # Assuming the first item is the one we need
        return response['items'][0]['id']
    else:
        return None

# The username portion from the channel URL (for https://www.youtube.com/@NutritionFactsOrg, it's 'NutritionFactsOrg')
username = 'NutritionFactsOrg'

channel_id = get_channel_id_by_username(username)
if channel_id:
    print(f'Channel ID for {username}: {channel_id}')
else:
    print('Channel ID not found.')
# Out:
# Channel ID for NutritionFactsOrg: UCddn8dUxYdgJz3Qr5mjADtA

# %%
# How many videos does the channel have?

def get_channel_video_count(channel_id):
    request = youtube.channels().list(
        part='statistics',
        id=channel_id
    )
    response = request.execute()
    
    if response['items']:
        # Assuming the channel is found and the first item is the target channel
        return response['items'][0]['statistics']['videoCount']
    else:
        return None

video_count = get_channel_video_count(channel_id)
if video_count is not None:
    print(f"The channel has {video_count} videos.")
else:
    print("Channel not found or error occurred.")
# Out:
# The channel has 2596 videos.

# %%
# Get info on videos in the channel
#https://developers.google.com/youtube/v3/docs/search

def get_channel_video_data(channel_id, max_results=50):
    #Initialize list to hold video data
    videos = []

    # Fetch videos from a specific channel
    res = youtube.search().list(part="snippet", channelId=channel_id, maxResults=max_results, type="video").execute()
    
    for item in res['items']:
        video_id = item['id']['videoId']
        playlist_id = item['id'].get('playlistId')
        video_title = item['snippet'].get('title')
        video_description = item['snippet'].get('description')
        upload_date = item['snippet'].get('publishedAt')

    # Append a dictionary of this information to our list
        videos.append({
            'video_id': video_id,
            'playlist_id': playlist_id,
            'title': video_title,
            'description': video_description,
            'upload_date': upload_date
        })

    # Convert the list of dictionaries into a DataFrame
    df_videos = pd.DataFrame(videos)

    return df_videos

df_videos = get_channel_video_data(channel_id, max_results=50)
df_videos
# Out:
#        video_id playlist_id  \
# 0   hUi4ii-0Cfc        None
# 1   gm-UcdE3nTQ        None
# 2   UVH7S6xCKIE        None
# 3   w5bG_0ubO0E        None
# 4   5fgVDT0qw88        None
# 5   E_3V58sPR9M        None
# 6   pSDedXTsQkE        None
# 7   -_w2WchC_fs        None
# 8   ZcL6qyc76Xg        None
# 9   tYaWLWBcSLk        None
# 10  N5rcQBVf-_E        None
# 11  H6XfUrAct6U        None
# 12  PfxrhimGIvg        None
# 13  uDNHIdWXjLY        None
# 14  fBwU4ElBJxU        None
# 15  0BEKEqtwlY8        None
# 16  YYw46D7TJgg        None
# 17  wZLgy4dvM1Y        None
# 18  6Icpg2RWgZE        None
# 19  4ZEZYu_7zR4        None
# 20  Ha4eVtElOp0        None
# 21  578ybslz3IY        None
# 22  4vcl2rnyb-o        None
# 23  NYdi0RpI1SU        None
# 24  heVa8xtCDIU        None
# 25  L3xoGx1Gr1o        None
# 26  PKGkYORTvK0        None
# 27  zVwHnxL3j-k        None
# 28  LXigmGZk5FU        None
# 29  ydtK-MPyCig        None
# 30  0Mt_OxSKKZ0        None
# 31  86Uap_iFppo        None
# 32  gitX1ZsejJw        None
# 33  T4qLPCxJUU0        None
# 34  Opid_83-kSw        None
# 35  vmZqxJUSmdY        None
# 36  hXxFdBwvLRE        None
# 37  6AeJ_zmUbIw        None
# 38  4ZnZkpAufXU        None
# 39  n-YpZhWzxhs        None
# 40  MKFWvYtm6Ck        None
# 41  zbzkOdBsNkU        None
# 42  mryzkO5QWWY        None
# 43  lakaozfALho        None
# 44  Eg5ksHXQavk        None
# 45  J-8nR9Ehx9M        None
# 46  Ig_ZWdpriC4        None
# 47  42qdqjF4OKk        None
# 48  AoHvkrcr6EM        None
# 49  bfERQJLvo6A        None
#
#                                                 title  \
# 0             Citrus Peels and Cancer: Zest for Life?
# 1                        Reversing Diabetes with Food
# 2                          Recipe: Morning Grain Bowl
# 3   Should Probiotics Be Taken Before, During, or ...
# 4                      Should We Take a Multivitamin?
# 5          How to Strengthen the Mind-Body Connection
# 6       Which Fruits and Vegetables Boost DNA Repair?
# 7                            Recipe: Soba Noodle Soup
# 8    Best Food to Prevent Common Childhood Infections
# 9                        How Not to Die from Diabetes
# 10                    Treating Gout with Cherry Juice
# 11       Treating Asthma With Plants vs. Supplements?
# 12        Which Are Better: Chia Seeds or Flax Seeds?
# 13                      Canned Beans or Cooked Beans?
# 14         Treating Parkinson&#39;s Disease with Diet
# 15                         Coffee and Artery Function
# 16                      Dietary Treatment of Glaucoma
# 17                      New Sponsorship: Big Broccoli
# 18                           Are Organic Foods Safer?
# 19  Paleopoo: What We Can Learn from Fossilized Feces
# 20  Peppers and Parkinson’s: The Benefits of Smoki...
# 21               Turmeric Curcumin and Osteoarthritis
# 22             Turmeric or Curcumin: Plants vs. Pills
# 23                   Beans and the Second Meal Effect
# 24             Benefits of Brewers Yeast for Diabetes
# 25                               Optimal Vinegar Dose
# 26      Benefits of Quinoa for Lowering Triglycerides
# 27  Culture Shock - Questioning the Efficacy and S...
# 28                  How Not to Die from Heart Disease
# 29                                 How to Cook Greens
# 30                        Walnuts and Artery Function
# 31   The Benefits of Kale and Cabbage for Cholesterol
# 32  Could Lactose Explain the Milk - Parkinson’s D...
# 33  The 5-2 Diet and the Fasting-Mimicking Diet Pu...
# 34                      Is Cheese Really Bad for You?
# 35                   Anti-Inflammatory Diet for Lupus
# 36                  Benefits of Lentils and Chickpeas
# 37                    Recipe: Veggie Mac &amp; Cheese
# 36  Lentils and garbanzo beans are put to the test...  2018-08-10T11:59:50Z
# 37  A cruciferous spin on macaroni and cheese, thi...  2019-08-14T11:59:49Z
# 38  Cocoa and nitrite-rich vegetables, such as gre...  2018-11-12T13:00:16Z
# 39  A whole food plant-based diet can be used to h...  2020-03-18T11:59:46Z
# 40  Eating every other day can raise your choleste...  2019-11-13T12:59:56Z
# 41  On a puff-by-puff basis, cannabis smoke deposi...  2018-10-03T11:38:49Z
# 42  The traditional Okinawa diet is centered aroun...  2015-10-02T11:34:47Z
# 43  Why don't authorities advocate a sufficient re...  2015-01-29T17:04:47Z
# 44  Given their oxalate content, how much is too m...  2019-06-19T11:59:51Z
# 45  The nutritional benefits of guacamole extend b...  2018-04-13T12:06:44Z
# 46  Here is the latest research on the effect of f...  2020-03-16T11:59:50Z
# 47  The effect of diet on cancer metastasis. Rando...  2021-06-09T11:59:46Z
# 48  Within hours of eating an unhealthy meal, we c...  2017-04-19T12:03:18Z
# 49  The effects of spinach and berries on oxidativ...  2018-06-06T12:07:03Z

# %%
# Save video list
df_videos.to_csv('../data/nutrition_facts_videos_50.csv')

# %%
# Get more than 50 videos

def get_channel_video_data(channel_id, max_results=50):
    #Initialize list to hold video data
    videos = []
    nextPageToken = None

    while True:

        # Fetch videos from a specific channel
        res = youtube.search().list(part="snippet", 
                                    channelId=channel_id, 
                                    maxResults=max_results, 
                                    type="video",
                                    pageToken=nextPageToken).execute()
        
        for item in res['items']:
            video_id = item['id']['videoId']
            playlist_id = item['id'].get('playlistId')
            video_title = item['snippet'].get('title')
            video_description = item['snippet'].get('description')
            upload_date = item['snippet'].get('publishedAt')

        # Append a dictionary of this information to our list
            videos.append({
                'video_id': video_id,
                'playlist_id': playlist_id,
                'title': video_title,
                'description': video_description,
                'upload_date': upload_date
            })

        # Check if there's a next page
        nextPageToken = res.get('nextPageToken')
        if not nextPageToken:
            break
    

    # Convert the list of dictionaries into a DataFrame
    df_videos = pd.DataFrame(videos)

    return df_videos

df_videos = get_channel_video_data(channel_id)
df_videos
# Out:
#         video_id playlist_id  \
# 0    hUi4ii-0Cfc        None
# 1    gm-UcdE3nTQ        None
# 2    E_3V58sPR9M        None
# 3    5fgVDT0qw88        None
# 4    ZcL6qyc76Xg        None
# ..           ...         ...
# 502  Ld0BdqvMFI4        None
# 503  6dmJpRfjvio        None
# 504  07vk6TuLw1Q        None
# 505  dfOdps2bppY        None
# 506  sEfJLc0NT9E        None
#
#                                                  title  \
# 0              Citrus Peels and Cancer: Zest for Life?
# 1                         Reversing Diabetes with Food
# 2           How to Strengthen the Mind-Body Connection
# 3                       Should We Take a Multivitamin?
# 4     Best Food to Prevent Common Childhood Infections
# ..                                                 ...
# 502                             Is Obesity Infectious?
# 503  Sugar Industry Attempts to Manipulate the Science
# 504  Highlights from the 2020 Dietary Guidelines He...
# 505     9 out of 10 Women Misinformed about Mammograms
# 506                    The Pros and Cons of Mammograms
#
#                                            description           upload_date
# 0    The reason eating citrus fruit appears to prot...  2016-05-18T11:56:55Z
# 1    Type 2 diabetes can be reversed with severe ca...  2016-03-02T12:57:10Z
# 2    Slow paced breathing at the right frequency ca...  2017-02-24T12:59:10Z
# 3    New subscribers to our e-newsletter always rec...  2014-01-31T12:11:34Z
# 4    Just a dusting of nutritional yeast worth of b...  2017-11-08T12:57:12Z
# ..                                                 ...                   ...
# 502  Given the role our gut bacteria can play in af...  2017-01-20T13:10:50Z
# 503  How the food industry responds to “health food...  2019-04-22T11:40:39Z
# 504  I was honored to testify before the US governm...  2019-10-09T12:00:09Z
# 505  Most women are just being told what to do, rat...  2018-01-22T13:08:13Z
# 506  Fact Boxes can quantify benefits and harms in ...  2018-03-12T11:57:18Z
#
# [507 rows x 5 columns]

# %%
# Save video list
df_videos.to_csv('../data/nutrition_facts_videos_500.csv')

# %%
# Get a list of videos in the given channel
response = youtube.channels().list(part='contentDetails', id=channel_id).execute()
playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# Get a list of videos in the channel's uploads playlist
videos = []
next_page_token = None
while True:
    if next_page_token is None:
        response = youtube.playlistItems().list(part='snippet', playlistId=playlist_id, maxResults=50).execute()
    else:
        response = youtube.playlistItems().list(part='snippet', playlistId=playlist_id, maxResults=50, pageToken=next_page_token).execute()

    for item in response['items']:
        videos.append({
            'videoId': item['snippet']['resourceId']['videoId'],
            'title': item['snippet']['title'],
            'description': item['snippet']['description'],
            'publishedAt': item['snippet']['publishedAt']
        })

    next_page_token = response.get('nextPageToken')
    if next_page_token is None:
        break

# Create a DataFrame from the list of videos
df = pd.DataFrame(videos)

df
# Out:
#           videoId                                              title  \
# 0     r3PuCQ8CxTc  Benefits and Side Effects of the Pneumonia Vac...
# 1     Oc8T8OGKnZ8                           Live Q&A with Dr. Greger
# 2     oa6UtySJKFE       Benefits and Side Effects of the Flu Vaccine
# 3     wZLgy4dvM1Y                      New Sponsorship: Big Broccoli
# 4     Et0lozAIbI8    Friday Favorites: Removing Warts with Duct Tape
# ...           ...                                                ...
# 2592  P_X3exQtuGA                          The Healthiest Herbal Tea
# 2593  ce-pvksbiwM                               Update on Yerba Maté
# 2594  1Yb5MjU38ng                                      Update on MSG
# 2595  lD2RzNJYGxQ                             Update on Juice Plus+®
# 2596  yEDHcD1DnCQ                               Update on Herbalife®
#
#                                             description           publishedAt
# 0     Randomized controlled trials have found that p...  2024-04-10T11:59:52Z
# 1     Join Dr. Greger on Thursday, April 25 at 3:00 ...  2024-04-09T19:50:43Z
# 2     Flu shots can prevent more than just the flu. ...  2024-04-08T11:59:55Z
# 3     Help keep us ad- and sponsorship-free by makin...  2024-04-07T15:59:56Z
# 4     Duct tape beat out cryotherapy (freezing) and ...  2024-04-05T11:59:52Z
# ...                                                 ...                   ...
# 2592  New subscribers to our e-newsletter always rec...  2011-02-08T14:59:42Z
# 2593  New subscribers to our e-newsletter always rec...  2011-02-08T14:57:18Z
# 2594  New subscribers to our e-newsletter always rec...  2011-02-08T14:48:31Z
# 2595  New subscribers to our e-newsletter always rec...  2011-02-08T05:41:12Z
# 2596  New subscribers to our e-newsletter always rec...  2011-02-08T05:38:58Z
#
# [2597 rows x 4 columns]

# %%
# Save video list
# df.to_csv('../data/nutrition_facts_videos_2597_2024-04-10.csv')

# %%
# you need to get the uploads playlist in order to get all the videos...
response = youtube.channels().list(part='contentDetails', id=channel_id).execute()
playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# %%
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '7whv3ksMb8m-duWjB6ji9qJLgck',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'xeYzVPBU-CLqmwmPx42v0w0V8p8',
#    'id': 'UCddn8dUxYdgJz3Qr5mjADtA',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUddn8dUxYdgJz3Qr5mjADtA'}}}]}
